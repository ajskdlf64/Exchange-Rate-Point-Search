# %% [markdown]
# ### 01. 환율 정보

# %%
import pandas as pd 
Dataset = pd.read_csv('../data/DAILY_DATA.csv')
Dataset = Dataset.set_index('date')
Dataset  = Dataset['2018-01-02':'2019-12-31']

# BND 제거
del Dataset['BND']

# %% [markdown]
# ### 2. 비트코인

# %%
# 경고 메세지 안뜨게 하기
import warnings
warnings.filterwarnings(action='ignore') 

# 데이터 불러오기
import pandas as pd
bitcoin = pd.read_csv('../data/Bitcoin.csv')

# 날짜 형식 변경하기
date = bitcoin['날짜'].apply(lambda x : x.replace('년 ','-'))\
                     .apply(lambda x : x.replace('월 ','-'))\
                     .apply(lambda x : x.replace('일',''))
bitcoin['날짜'] = date

# 칼럼명 변경하기
bitcoin.columns = ['date', 'BITCOIN', 'open', 'high', 'low', 'volume', 'rate']

# 날짜 인덱스로 변경하기
bitcoin = bitcoin.set_index('date')

# 비트코인 값 양식 바꾸기
value = bitcoin['BITCOIN'].apply(lambda x : x.replace(',','')).apply(lambda x : float(x))

# 데이터 프레임을 변경하기
bitcoin = pd.DataFrame(value)

# 2018년 2월 데이터부터 추출하고, 기존 데이터와 merge
Dataset = pd.concat([Dataset, bitcoin], axis=1)
Dataset = Dataset.dropna()

# %% [markdown]
# ### 3. 테더

# %%
# 데이터 불러오기
import pandas as pd
tether = pd.read_csv('../data/tether.csv')

# 날짜에 필요없는 부분 제거
date = tether['snapped_at'].apply(lambda x : x.replace(' 00:00:00 UTC',''))
tether['date'] = date

# 날짜를 인덱스로 바꾸기
tether = tether.set_index('date')

# 칼럼명 지정하기
tether.columns = ['time', 'TETHER', 'market_cap', 'total_volume']

# 테더만 빼오기
tether = tether['TETHER']

# 기존 데이터와 merge
Dataset = pd.concat([Dataset, tether], axis=1)
Dataset = Dataset.dropna()

# %% [markdown]
# ### KOSPI 200

# %%
# 데이터 불러오기
import pandas as pd
kospi200 = pd.read_csv('../data/KOSPI200.csv')

# 날짜 형식 변경하기
date = kospi200['날짜'].apply(lambda x : x.replace('년 ','-'))\
                     .apply(lambda x : x.replace('월 ','-'))\
                     .apply(lambda x : x.replace('일',''))
kospi200['날짜'] = date

# 칼럼명 변경하기
kospi200.columns = ['date', 'KOSPI200', 'open', 'high', 'low', 'volume', 'rate']

# 날짜 인덱스로 변경하기
kospi200 = kospi200.set_index('date')

# 종가만 빼오기
kospi200 = kospi200['KOSPI200']

# 기존 데이터와 merge
Dataset = pd.concat([Dataset, kospi200], axis=1)
Dataset = Dataset.dropna()

# %% [markdown]
# ### KOSDAQ

# %%
# 데이터 불러오기
import pandas as pd
kosdaq = pd.read_csv('../data/KOSDAQ.csv')

# 날짜 형식 변경하기
date = kosdaq['날짜'].apply(lambda x : x.replace('년 ','-'))\
                     .apply(lambda x : x.replace('월 ','-'))\
                     .apply(lambda x : x.replace('일',''))
kosdaq['날짜'] = date

# 칼럼명 변경하기
kosdaq.columns = ['date', 'KOSDAQ', 'open', 'high', 'low', 'volume', 'rate']

# 날짜 인덱스로 변경하기
kosdaq = kosdaq.set_index('date')

# 종가만 빼오기
kosdaq = kosdaq['KOSDAQ']

# 기존 데이터와 merge
Dataset = pd.concat([Dataset, kosdaq], axis=1)
Dataset = Dataset.dropna()

# %% [markdown]
# ### SAMSUNG

# %%
# 데이터 불러오기
import pandas as pd
samsung = pd.read_csv('../data/SAMSUNG.csv')

# 날짜 형식 변경하기
date = samsung['날짜'].apply(lambda x : x.replace('년 ','-'))\
                     .apply(lambda x : x.replace('월 ','-'))\
                     .apply(lambda x : x.replace('일',''))
samsung['날짜'] = date

# 칼럼명 변경하기
samsung.columns = ['date', 'SAMSUNG', 'open', 'high', 'low', 'volume', 'rate']

# 날짜 인덱스로 변경하기
samsung = samsung.set_index('date')

# 값 양식 바꾸기
value = samsung['SAMSUNG'].apply(lambda x : x.replace(',','')).apply(lambda x : float(x))

# 데이터 프레임을 변경하기
samsung = pd.DataFrame(value)

# 종가만 빼오기
samsung = samsung['SAMSUNG']

# 기존 데이터와 merge
Dataset = pd.concat([Dataset, samsung], axis=1)
Dataset = Dataset.dropna()

# %% [markdown]
# ### S&P 500

# %%
# 데이터 불러오기
import pandas as pd
sp500 = pd.read_csv('../data/S&P500.csv')

# 날짜 형식 변경하기
date = sp500['날짜'].apply(lambda x : x.replace('년 ','-'))\
                     .apply(lambda x : x.replace('월 ','-'))\
                     .apply(lambda x : x.replace('일',''))
sp500['날짜'] = date

# 칼럼명 변경하기
sp500.columns = ['date', 'S&P500', 'open', 'high', 'low', 'volume', 'rate']

# 날짜 인덱스로 변경하기
sp500 = sp500.set_index('date')

# 값 양식 바꾸기
value = sp500['S&P500'].apply(lambda x : x.replace(',','')).apply(lambda x : float(x))

# 데이터 프레임을 변경하기
sp500 = pd.DataFrame(value)

# 종가만 빼오기
sp500 = sp500['S&P500']

# 기존 데이터와 merge
Dataset = pd.concat([Dataset, sp500], axis=1)
Dataset = Dataset.dropna()

# %% [markdown]
# ### DOWS JONES

# %%
# 데이터 불러오기
import pandas as pd
dowjones = pd.read_csv('../data/DOWSJONES.csv')

# 날짜 형식 변경하기
date = dowjones['날짜'].apply(lambda x : x.replace('년 ','-'))\
                      .apply(lambda x : x.replace('월 ','-'))\
                      .apply(lambda x : x.replace('일',''))
dowjones['날짜'] = date

# 칼럼명 변경하기
dowjones.columns = ['date', 'DOWJONES', 'open', 'high', 'low', 'volume', 'rate']

# 날짜 인덱스로 변경하기
dowjones = dowjones.set_index('date')

# 값 양식 바꾸기
value = dowjones['DOWJONES'].apply(lambda x : x.replace(',','')).apply(lambda x : float(x))

# 데이터 프레임을 변경하기
dowjones = pd.DataFrame(value)

# 종가만 빼오기
dowjones = dowjones['DOWJONES']

# 기존 데이터와 merge
Dataset = pd.concat([Dataset, dowjones], axis=1)
Dataset = Dataset.dropna()

# %% [markdown]
# ### NASDAQ

# %%
# 데이터 불러오기
import pandas as pd
nasdaq = pd.read_csv('../data/NASDAQ.csv')

# 날짜 형식 변경하기
date = nasdaq['날짜'].apply(lambda x : x.replace('년 ','-'))\
                      .apply(lambda x : x.replace('월 ','-'))\
                      .apply(lambda x : x.replace('일',''))
nasdaq['날짜'] = date

# 칼럼명 변경하기
nasdaq.columns = ['date', 'NASDAQ', 'open', 'high', 'low', 'volume', 'rate']

# 날짜 인덱스로 변경하기
nasdaq = nasdaq.set_index('date')

# 값 양식 바꾸기
value = nasdaq['NASDAQ'].apply(lambda x : x.replace(',','')).apply(lambda x : float(x))

# 데이터 프레임을 변경하기
nasdaq = pd.DataFrame(value)

# 종가만 빼오기
nasdaq = nasdaq['NASDAQ']

# 기존 데이터와 merge
Dataset = pd.concat([Dataset, nasdaq], axis=1)
Dataset = Dataset.dropna()

# %% [markdown]
# ### MICROSOFT

# %%
# 데이터 불러오기
import pandas as pd
microsoft = pd.read_csv('../data/MICROSOFT.csv')

# 날짜 형식 변경하기
date = microsoft['날짜'].apply(lambda x : x.replace('년 ','-'))\
                       .apply(lambda x : x.replace('월 ','-'))\
                       .apply(lambda x : x.replace('일',''))
microsoft['날짜'] = date

# 칼럼명 변경하기
microsoft.columns = ['date', 'MICROSOFT', 'open', 'high', 'low', 'volume', 'rate']

# 날짜 인덱스로 변경하기
microsoft = microsoft.set_index('date')

# 종가만 빼오기
microsoft = microsoft['MICROSOFT']

# 기존 데이터와 merge
Dataset = pd.concat([Dataset, microsoft], axis=1)
Dataset = Dataset.dropna()

# %% [markdown]
# ### APPLE

# %%
# 데이터 불러오기
import pandas as pd
apple = pd.read_csv('../data/APPLE.csv')

# 날짜 형식 변경하기
date = apple['날짜'].apply(lambda x : x.replace('년 ','-'))\
                   .apply(lambda x : x.replace('월 ','-'))\
                   .apply(lambda x : x.replace('일',''))
apple['날짜'] = date

# 칼럼명 변경하기
apple.columns = ['date', 'APPLE', 'open', 'high', 'low', 'volume', 'rate']

# 날짜 인덱스로 변경하기
apple = apple.set_index('date')

# 종가만 빼오기
apple = apple['APPLE']

# 기존 데이터와 merge
Dataset = pd.concat([Dataset, apple], axis=1)
Dataset = Dataset.dropna()

# %% [markdown]
# ### US LIBOR

# %%
# 데이터 불러오기
import pandas as pd
us_libor = pd.read_csv('../data/US_LIBOR.csv')

# 칼럼명 변경하기
us_libor.columns = ['date', 'US_LIBOR']

# 날짜 인덱스로 변경하기
us_libor = us_libor.set_index('date')

# 종가만 빼오기
us_libor = us_libor['US_LIBOR']

# 기존 데이터와 merge
Dataset = pd.concat([Dataset, us_libor], axis=1)
Dataset = Dataset.dropna()

# %% [markdown]
# ### KOR LIBOR

# %%
# 데이터 불러오기
import pandas as pd
kor_libor = pd.read_csv('../data/KOR_LIBOR.csv')

# 칼럼명 변경하기
kor_libor.columns = ['date', '1weekday', '1month', '2month', 'KOR_LIBOR', '6month', '12month']

# 날짜 인덱스로 변경하기
kor_libor = kor_libor.set_index('date')

# 종가만 빼오기
kor_libor = kor_libor['KOR_LIBOR']

# 기존 데이터와 merge
Dataset = pd.concat([Dataset, kor_libor], axis=1)
Dataset = Dataset.dropna()

# %% [markdown]
# ### 미국 1년 채권 수익률

# %%
# 데이터 불러오기
import pandas as pd
us_bond_rate_1years = pd.read_csv('../data/US_BOND_RATE_1YEARS.csv')

# 날짜 형식 변경하기
date = us_bond_rate_1years['날짜'].apply(lambda x : x.replace('년 ','-'))\
                                 .apply(lambda x : x.replace('월 ','-'))\
                                 .apply(lambda x : x.replace('일',''))
us_bond_rate_1years['날짜'] = date

# 칼럼명 변경하기
us_bond_rate_1years.columns = ['date', 'US_BOND_RATE_1YEARS', 'open', 'high', 'low', 'rate']

# 날짜 인덱스로 변경하기
us_bond_rate_1years = us_bond_rate_1years.set_index('date')

# 종가만 빼오기
us_bond_rate_1years = us_bond_rate_1years['US_BOND_RATE_1YEARS']

# 기존 데이터와 merge
Dataset = pd.concat([Dataset, us_bond_rate_1years], axis=1)
Dataset = Dataset.dropna()

# %% [markdown]
# ### 미국 2년 채권 수익률

# %%
# 데이터 불러오기
import pandas as pd
us_bond_rate_2years = pd.read_csv('../data/US_BOND_RATE_2YEARS.csv')

# 날짜 형식 변경하기
date = us_bond_rate_2years['날짜'].apply(lambda x : x.replace('년 ','-'))\
                   .apply(lambda x : x.replace('월 ','-'))\
                   .apply(lambda x : x.replace('일',''))
us_bond_rate_2years['날짜'] = date

# 칼럼명 변경하기
us_bond_rate_2years.columns = ['date', 'US_BOND_RATE_2YEARS', 'open', 'high', 'low', 'rate']

# 날짜 인덱스로 변경하기
us_bond_rate_2years = us_bond_rate_2years.set_index('date')

# 종가만 빼오기
us_bond_rate_2years = us_bond_rate_2years['US_BOND_RATE_2YEARS']

# 기존 데이터와 merge
Dataset = pd.concat([Dataset, us_bond_rate_2years], axis=1)
Dataset = Dataset.dropna()

# %% [markdown]
# ### 미국 10년 채권 수익률

# %%
# 데이터 불러오기
import pandas as pd
us_bond_rate_10years = pd.read_csv('../data/US_BOND_RATE_10YEARS.csv')

# 날짜 형식 변경하기
date = us_bond_rate_10years['날짜'].apply(lambda x : x.replace('년 ','-'))\
                                  .apply(lambda x : x.replace('월 ','-'))\
                                  .apply(lambda x : x.replace('일',''))
us_bond_rate_10years['날짜'] = date

# 칼럼명 변경하기
us_bond_rate_10years.columns = ['date', 'US_BOND_RATE_10YEARS', 'open', 'high', 'low', 'rate']

# 날짜 인덱스로 변경하기
us_bond_rate_10years = us_bond_rate_10years.set_index('date')

# 종가만 빼오기
us_bond_rate_10years = us_bond_rate_10years['US_BOND_RATE_10YEARS']

# 기존 데이터와 merge
Dataset = pd.concat([Dataset, us_bond_rate_10years], axis=1)
Dataset = Dataset.dropna()

# %% [markdown]
# ### 현대 자동차

# %%
# 데이터 불러오기
import pandas as pd
hyundai_car = pd.read_csv('../data/HYUNDAI_CAR.csv')

# 날짜 형식 변경하기
date = hyundai_car['날짜'].apply(lambda x : x.replace('년 ','-'))\
                         .apply(lambda x : x.replace('월 ','-'))\
                         .apply(lambda x : x.replace('일',''))
hyundai_car['날짜'] = date

# 칼럼명 변경하기
hyundai_car.columns = ['date', 'HYUNDAI_CAR', 'open', 'high', 'low', 'volume', 'rate']

# 날짜 인덱스로 변경하기
hyundai_car = hyundai_car.set_index('date')

# 값 양식 바꾸기
value = hyundai_car['HYUNDAI_CAR'].apply(lambda x : x.replace(',','')).apply(lambda x : float(x))

# 데이터 프레임을 변경하기
hyundai_car = pd.DataFrame(value)

# 종가만 빼오기
hyundai_car = hyundai_car['HYUNDAI_CAR']

# 기존 데이터와 merge
Dataset = pd.concat([Dataset, hyundai_car], axis=1)
Dataset = Dataset.dropna()

# %% [markdown]
# ### IEF US

# %%
# 데이터 불러오기
import pandas as pd
ief_us = pd.read_csv('../data/IEF_US.csv')

# 날짜 형식 변경하기
date = ief_us['날짜'].apply(lambda x : x.replace('년 ','-'))\
                         .apply(lambda x : x.replace('월 ','-'))\
                         .apply(lambda x : x.replace('일',''))
ief_us['날짜'] = date

# 칼럼명 변경하기
ief_us.columns = ['date', 'IEF_US', 'open', 'high', 'low', 'volume', 'rate']

# 날짜 인덱스로 변경하기
ief_us = ief_us.set_index('date')

# 종가만 빼오기
ief_us = ief_us['IEF_US']

# 기존 데이터와 merge
Dataset = pd.concat([Dataset, ief_us], axis=1)
Dataset = Dataset.dropna()

# %% [markdown]
# ### GLD_US

# %%
# 데이터 불러오기
import pandas as pd
gld_us = pd.read_csv('../data/GLD_US.csv')

# 날짜 형식 변경하기
date = gld_us['날짜'].apply(lambda x : x.replace('년 ','-'))\
                    .apply(lambda x : x.replace('월 ','-'))\
                    .apply(lambda x : x.replace('일',''))
gld_us['날짜'] = date

# 칼럼명 변경하기
gld_us.columns = ['date', 'GLD_US', 'open', 'high', 'low', 'volume', 'rate']

# 날짜 인덱스로 변경하기
gld_us = gld_us.set_index('date')

# 종가만 빼오기
gld_us = gld_us['GLD_US']

# 기존 데이터와 merge
Dataset = pd.concat([Dataset, gld_us], axis=1)
Dataset = Dataset.dropna()

# %% [markdown]
# ### 홍콩 항셍

# %%
# 데이터 불러오기
import pandas as pd
hsi = pd.read_csv('../data/HSI.csv')

# 날짜 형식 변경하기
date = hsi['날짜'].apply(lambda x : x.replace('년 ','-'))\
                    .apply(lambda x : x.replace('월 ','-'))\
                    .apply(lambda x : x.replace('일',''))
hsi['날짜'] = date

# 칼럼명 변경하기
hsi.columns = ['date', 'HSI', 'open', 'high', 'low', 'volume', 'rate']

# 날짜 인덱스로 변경하기
hsi = hsi.set_index('date')

# 값 양식 바꾸기
value = hsi['HSI'].apply(lambda x : x.replace(',','')).apply(lambda x : float(x))

# 데이터 프레임을 변경하기
hsi = pd.DataFrame(value)

# 종가만 빼오기
hsi = hsi['HSI']

# 기존 데이터와 merge
Dataset = pd.concat([Dataset, hsi], axis=1)
Dataset = Dataset.dropna()

# %% [markdown]
# ### NAVER

# %%
# 데이터 불러오기
import pandas as pd
naver = pd.read_csv('../data/NAVER.csv')

# 날짜 형식 변경하기
date = naver['날짜'].apply(lambda x : x.replace('년 ','-'))\
                   .apply(lambda x : x.replace('월 ','-'))\
                   .apply(lambda x : x.replace('일',''))
naver['날짜'] = date

# 칼럼명 변경하기
naver.columns = ['date', 'NAVER', 'open', 'high', 'low', 'volume', 'rate']

# 날짜 인덱스로 변경하기
naver = naver.set_index('date')

# 값 양식 바꾸기
value = naver['NAVER'].apply(lambda x : x.replace(',','')).apply(lambda x : float(x))

# 데이터 프레임을 변경하기
naver = pd.DataFrame(value)

# 종가만 빼오기
naver = naver['NAVER']

# 기존 데이터와 merge
Dataset = pd.concat([Dataset, naver], axis=1)
Dataset = Dataset.dropna()

# %% [markdown]
# ### SK HYNIX

# %%
# 데이터 불러오기
import pandas as pd
sk_hynix = pd.read_csv('../data/SK_HYNIX.csv')

# 날짜 형식 변경하기
date = sk_hynix['날짜'].apply(lambda x : x.replace('년 ','-'))\
                      .apply(lambda x : x.replace('월 ','-'))\
                      .apply(lambda x : x.replace('일',''))
sk_hynix['날짜'] = date

# 칼럼명 변경하기
sk_hynix.columns = ['date', 'SK_HYNIX', 'open', 'high', 'low', 'volume', 'rate']

# 날짜 인덱스로 변경하기
sk_hynix = sk_hynix.set_index('date')

# 값 양식 바꾸기
value = sk_hynix['SK_HYNIX'].apply(lambda x : x.replace(',','')).apply(lambda x : float(x))

# 데이터 프레임을 변경하기
sk_hynix = pd.DataFrame(value)

# 종가만 빼오기
sk_hynix = sk_hynix['SK_HYNIX']

# 기존 데이터와 merge
Dataset = pd.concat([Dataset, sk_hynix], axis=1)
Dataset = Dataset.dropna()

# %% [markdown]
# ### AMAZON

# %%
# 데이터 불러오기
import pandas as pd
amazon = pd.read_csv('../data/AMAZON.csv')

# 날짜 형식 변경하기
date = amazon['날짜'].apply(lambda x : x.replace('년 ','-'))\
                      .apply(lambda x : x.replace('월 ','-'))\
                      .apply(lambda x : x.replace('일',''))
amazon['날짜'] = date

# 칼럼명 변경하기
amazon.columns = ['date', 'AMAZON', 'open', 'high', 'low', 'volume', 'rate']

# 날짜 인덱스로 변경하기
amazon = amazon.set_index('date')

# 값 양식 바꾸기
value = amazon['AMAZON'].apply(lambda x : x.replace(',','')).apply(lambda x : float(x))

# 데이터 프레임을 변경하기
amazon = pd.DataFrame(value)

# 종가만 빼오기
amazon = amazon['AMAZON']

# 기존 데이터와 merge
Dataset = pd.concat([Dataset, amazon], axis=1)
Dataset = Dataset.dropna()

# %% [markdown]
# ### TESLA

# %%
# 데이터 불러오기
import pandas as pd
tesla = pd.read_csv('../data/TESLA.csv')

# 날짜 형식 변경하기
date = tesla['날짜'].apply(lambda x : x.replace('년 ','-'))\
                      .apply(lambda x : x.replace('월 ','-'))\
                      .apply(lambda x : x.replace('일',''))
tesla['날짜'] = date

# 칼럼명 변경하기
tesla.columns = ['date', 'TESLA', 'open', 'high', 'low', 'volume', 'rate']

# 날짜 인덱스로 변경하기
tesla = tesla.set_index('date')

# 종가만 빼오기
tesla = tesla['TESLA']

# 기존 데이터와 merge
Dataset = pd.concat([Dataset, tesla], axis=1)
Dataset = Dataset.dropna()

# %% [markdown]
# ### NIKKEI

# %%
# 데이터 불러오기
import pandas as pd
nikkei = pd.read_csv('../data/NIKKEI.csv')

# 날짜 형식 변경하기
date = nikkei['날짜'].apply(lambda x : x.replace('년 ','-'))\
                      .apply(lambda x : x.replace('월 ','-'))\
                      .apply(lambda x : x.replace('일',''))
nikkei['날짜'] = date

# 칼럼명 변경하기
nikkei.columns = ['date', 'NIKKEI', 'open', 'high', 'low', 'volume', 'rate']

# 날짜 인덱스로 변경하기
nikkei = nikkei.set_index('date')

# 값 양식 바꾸기
value = nikkei['NIKKEI'].apply(lambda x : x.replace(',','')).apply(lambda x : float(x))

# 데이터 프레임을 변경하기
nikkei = pd.DataFrame(value)

# 종가만 빼오기
nikkei = nikkei['NIKKEI']

# 기존 데이터와 merge
Dataset = pd.concat([Dataset, nikkei], axis=1)
Dataset = Dataset.dropna()

# %% [markdown]
# ### FTSE

# %%
# 데이터 불러오기
import pandas as pd
ftse = pd.read_csv('../data/FTSE.csv')

# 날짜 형식 변경하기
date = ftse['날짜'].apply(lambda x : x.replace('년 ','-'))\
                      .apply(lambda x : x.replace('월 ','-'))\
                      .apply(lambda x : x.replace('일',''))
ftse['날짜'] = date

# 칼럼명 변경하기
ftse.columns = ['date', 'FTSE', 'open', 'high', 'low', 'volume', 'rate']

# 날짜 인덱스로 변경하기
ftse = ftse.set_index('date')

# 값 양식 바꾸기
value = ftse['FTSE'].apply(lambda x : x.replace(',','')).apply(lambda x : float(x))

# 데이터 프레임을 변경하기
ftse = pd.DataFrame(value)

# 종가만 빼오기
ftse = ftse['FTSE']

# 기존 데이터와 merge
Dataset = pd.concat([Dataset, ftse], axis=1)
Dataset = Dataset.dropna()

# %% [markdown]
# ### BITCOIN_SV

# %%
# 데이터 불러오기
import pandas as pd
bitcoin_sv = pd.read_csv('../data/BITCOIN_SV.csv')

# 날짜 형식 변경하기
date = bitcoin_sv['날짜'].apply(lambda x : x.replace('년 ','-'))\
                        .apply(lambda x : x.replace('월 ','-'))\
                        .apply(lambda x : x.replace('일',''))
bitcoin_sv['날짜'] = date

# 칼럼명 변경하기
bitcoin_sv.columns = ['date', 'BITCOIN_SV', 'open', 'high', 'low', 'volume', 'rate']

# 날짜 인덱스로 변경하기
bitcoin_sv = bitcoin_sv.set_index('date')

# 종가만 빼오기
bitcoin_sv = bitcoin_sv['BITCOIN_SV']

# 기존 데이터와 merge
Dataset = pd.concat([Dataset, bitcoin_sv], axis=1)
Dataset = Dataset.dropna()

# %% [markdown]
# ### ETHEREUM

# %%
# 데이터 불러오기
import pandas as pd
ethereum = pd.read_csv('../data/ETHEREUM.csv')

# 날짜 형식 변경하기
date = ethereum['날짜'].apply(lambda x : x.replace('년 ','-'))\
                      .apply(lambda x : x.replace('월 ','-'))\
                      .apply(lambda x : x.replace('일',''))
ethereum['날짜'] = date

# 칼럼명 변경하기
ethereum.columns = ['date', 'ETHEREUM', 'open', 'high', 'low', 'volume', 'rate']

# 날짜 인덱스로 변경하기
ethereum = ethereum.set_index('date')

# 값 양식 바꾸기
value = ethereum['ETHEREUM'].apply(lambda x : x.replace(',','')).apply(lambda x : float(x))

# 데이터 프레임을 변경하기
ethereum = pd.DataFrame(value)

# 종가만 빼오기
ethereum = ethereum['ETHEREUM']

# 기존 데이터와 merge
Dataset = pd.concat([Dataset, ethereum], axis=1)
Dataset = Dataset.dropna()

# %% [markdown]
# ### ETHEREUM_CLASSIC

# %%
# 데이터 불러오기
import pandas as pd
ethereum_classic = pd.read_csv('../data/ETHEREUM_CLASSIC.csv')

# 날짜 형식 변경하기
date = ethereum_classic['날짜'].apply(lambda x : x.replace('년 ','-'))\
                              .apply(lambda x : x.replace('월 ','-'))\
                              .apply(lambda x : x.replace('일',''))
ethereum_classic['날짜'] = date

# 칼럼명 변경하기
ethereum_classic.columns = ['date', 'ETHEREUM_CLASSIC', 'open', 'high', 'low', 'volume', 'rate']

# 날짜 인덱스로 변경하기
ethereum_classic = ethereum_classic.set_index('date')

# 종가만 빼오기
ethereum_classic = ethereum_classic['ETHEREUM_CLASSIC']

# 기존 데이터와 merge
Dataset = pd.concat([Dataset, ethereum_classic], axis=1)
Dataset = Dataset.dropna()

# %% [markdown]
# ### EOS

# %%
# 데이터 불러오기
import pandas as pd
eos = pd.read_csv('../data/EOS.csv')

# 날짜 형식 변경하기
date = eos['날짜'].apply(lambda x : x.replace('년 ','-'))\
                      .apply(lambda x : x.replace('월 ','-'))\
                      .apply(lambda x : x.replace('일',''))
eos['날짜'] = date

# 칼럼명 변경하기
eos.columns = ['date', 'EOS', 'open', 'high', 'low', 'volume', 'rate']

# 날짜 인덱스로 변경하기
eos = eos.set_index('date')

# 종가만 빼오기
eos = eos['EOS']

# 기존 데이터와 merge
Dataset = pd.concat([Dataset, eos], axis=1)
Dataset = Dataset.dropna()

# %% [markdown]
# ### RIPPLE

# %%
# 데이터 불러오기
import pandas as pd
ripple = pd.read_csv('../data/RIPPLE.csv')

# 날짜 형식 변경하기
date = ripple['날짜'].apply(lambda x : x.replace('년 ','-'))\
                      .apply(lambda x : x.replace('월 ','-'))\
                      .apply(lambda x : x.replace('일',''))
ripple['날짜'] = date

# 칼럼명 변경하기
ripple.columns = ['date', 'RIPPLE', 'open', 'high', 'low', 'volume', 'rate']

# 날짜 인덱스로 변경하기
ripple = ripple.set_index('date')

# 종가만 빼오기
ripple = ripple['RIPPLE']

# 기존 데이터와 merge
Dataset = pd.concat([Dataset, ripple], axis=1)
Dataset = Dataset.dropna()

# %% [markdown]
# ### STELLAR

# %%
# 데이터 불러오기
import pandas as pd
stellar = pd.read_csv('../data/STELLA.csv')

# 날짜 형식 변경하기
date = stellar['날짜'].apply(lambda x : x.replace('년 ','-'))\
                      .apply(lambda x : x.replace('월 ','-'))\
                      .apply(lambda x : x.replace('일',''))
stellar['날짜'] = date

# 칼럼명 변경하기
stellar.columns = ['date', 'STELLA', 'open', 'high', 'low', 'volume', 'rate']

# 날짜 인덱스로 변경하기
stellar = stellar.set_index('date')

# 종가만 빼오기
stellar = stellar['STELLA']

# 기존 데이터와 merge
Dataset = pd.concat([Dataset, stellar], axis=1)
Dataset = Dataset.dropna()

# %% [markdown]
# ### Final Dataset (52 Features)

# %% [markdown]
# **1. 환율(21)**
#  - AED, &nbsp;&nbsp; AUD, &nbsp;&nbsp; BHD, &nbsp;&nbsp; CAD, &nbsp;&nbsp; CHF, &nbsp;&nbsp; CNH, &nbsp;&nbsp; DKK, &nbsp;&nbsp; EUR, &nbsp;&nbsp; GBP, &nbsp;&nbsp; HKD, &nbsp;&nbsp; IDR(100), &nbsp;&nbsp; JPY(100), &nbsp;&nbsp; KWD, &nbsp;&nbsp; MYR, &nbsp;&nbsp; NOK, &nbsp;&nbsp; NZD, &nbsp;&nbsp; SAR, &nbsp;&nbsp; SEK, &nbsp;&nbsp; SGD, &nbsp;&nbsp; THB, &nbsp;&nbsp; USD
#
# **2. 금리(7)**
#  - US_BOND_RATE_1YEARS, &nbsp;&nbsp; US_BOND_RATE_2YEARS, &nbsp;&nbsp; US_BOND_RATE_10YEARS, &nbsp;&nbsp; USLIBOR, &nbsp;&nbsp; KORLIBOR, &nbsp;&nbsp; IEF_US, &nbsp;&nbsp; GLD_US
#
# **3. 종목(8)**
#  - HYUNDAI_CAR, &nbsp;&nbsp; MICROSOFT, &nbsp;&nbsp; APPLE, &nbsp;&nbsp; SAMSUNG, &nbsp;&nbsp; SK HYNIX, &nbsp;&nbsp; AMAZON, &nbsp;&nbsp; TESLA, &nbsp;&nbsp; NAVER
#
# **4. 지수(8)**
#  - KOSPI200, &nbsp;&nbsp; KOSDAQ, &nbsp;&nbsp; S&P500, &nbsp;&nbsp; DOWJONES, &nbsp;&nbsp; NASDAQ,  &nbsp;&nbsp; HSI, &nbsp;&nbsp; FTSE,  &nbsp;&nbsp; NIKK255
#
# **5. 기타 종목(8)**
#  - BITCOIN,&nbsp;&nbsp; TETHER, &nbsp;&nbsp; BITCOIN_SV, &nbsp;&nbsp; ETHEREUM, &nbsp;&nbsp; ETHEREUM_CLASSIC, &nbsp;&nbsp; EOS, &nbsp;&nbsp; RIPPLE, &nbsp;&nbsp; STELLAR

# %%
Dataset
# Out:
#                AED     AUD      BHD     CAD      CHF     CNH     DKK      EUR  \
# 2018-11-19  307.28  825.98  2993.82  858.33  1129.15  162.86  172.68  1288.47
# 2018-11-20  306.93  822.33  2990.21  855.94  1135.18  162.58  173.04  1291.32
# 2018-11-21  306.96  813.21  2992.46  847.27  1133.22  162.54  171.82  1282.14
# 2018-11-26  307.77  818.09  2998.83  854.95  1133.50  163.05  171.75  1281.48
# 2018-11-27  307.61  815.67  2997.32  852.63  1131.60  162.81  171.58  1280.12
# ...            ...     ...      ...     ...      ...     ...     ...      ...
# 2019-12-20  317.03  801.58  3088.70  887.14  1190.39  166.42  173.38  1295.39
# 2019-12-23  316.53  801.96  3083.49  884.48  1183.37  166.14  172.40  1288.04
# 2019-12-24  316.53  801.96  3083.49  884.48  1183.37  165.80  172.40  1288.04
# 2019-12-27  316.13  806.28  3079.78  885.80  1183.57  166.09  172.60  1288.82
# 2019-12-30  316.05  810.31  3078.98  887.98  1192.07  165.87  173.77  1298.06
#
# ...

# %% [markdown]
# ### USD Correlation

# %% [markdown]
# ![dfdf](../figure/corr.png)

# %% [markdown]
# ### Data Save

# %%
Dataset.to_csv('../data/Dataset.csv')
