# %% [markdown]
# ### 1. Library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 2. Data Load

# %%
set1 = pd.read_csv('./data/set01.csv')
set2 = pd.read_csv('./data/set02.csv')
set3 = pd.read_csv('./data/set03.csv')
set4 = pd.read_csv('./data/set04.csv')
set5 = pd.read_csv('./data/set05.csv')
set6 = pd.read_csv('./data/set06.csv')
set7 = pd.read_csv('./data/set07.csv')
set8 = pd.read_csv('./data/set08.csv')
set9 = pd.read_csv('./data/set09.csv')
set10 = pd.read_csv('./data/set10.csv')
set11 = pd.read_csv('./data/set11.csv')
set12 = pd.read_csv('./data/set12.csv')

# %%
import numpy as np
import pandas as pd
import seaborn as sns
sns.set(style="whitegrid")

rs = np.random.RandomState(365)
values = rs.randn(365, 4).cumsum(axis=0)
dates = pd.date_range("1 1 2016", periods=365, freq="D")
data = pd.DataFrame(values, dates, columns=["A", "B", "C", "D"])
data = data.rolling(7).mean()

sns.lineplot(data=set1['Rate'], palette="tab10", linewidth=2.5)
plt.show()
